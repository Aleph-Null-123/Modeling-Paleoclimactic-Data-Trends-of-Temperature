# %%
data = start()
# Out:
# C:\Users\arjun\Documents\TS Math Project 5\data\117_723A.Godad.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: 117_723A.Godad.2011.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: 117_723A.Godad.2011
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\161_976.Martrat.2014.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: 161_976.Martrat.2014.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: 161_976.Martrat.2014
# Created time series: 11 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\165_1002C.Herbert.2000.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: 165_1002C.Herbert.2000.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: 165_1002C.Herbert.2000
# Created time series: 11 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\2005-804-006.Ledu.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: 2005-804-006.Ledu.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: 2005-804-006.Ledu.2010
# Created time series: 10 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\31Lake.Eisner.1995.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: 31Lake.Eisner.1995.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: 31Lake.Eisner.1995
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\3MPond.Pellatt.2000.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: 3MPond.Pellatt.2000.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: 3MPond.Pellatt.2000
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\850Lake.Shemesh.2001.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: 850Lake.Shemesh.2001.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: 850Lake.Shemesh.2001
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\893A.Kennet.2007.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: 893A.Kennet.2007.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: 893A.Kennet.2007
# Created time series: 17 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\A7.Sun.2005.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: A7.Sun.2005.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: A7.Sun.2005
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Abalone.Cole.1994.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Abalone.Cole.1994.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Abalone.Cole.1994
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\AdelaideTarn.Jara.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: AdelaideTarn.Jara.2015.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: AdelaideTarn.Jara.2015
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Agassiz.Lecavalier.2017.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Agassiz.Lecavalier.2017.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Agassiz.Lecavalier.2017
# Created time series: 14 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\AgeroedsMosse.Nilsson.1964.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: AgeroedsMosse.Nilsson.1964.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: AgeroedsMosse.Nilsson.1964
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\AjaxBog.Wilmshurst.2007.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: AjaxBog.Wilmshurst.2007.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: AjaxBog.Wilmshurst.2007
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\AlanenLaanijarvi.Heinrichs.2005.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: AlanenLaanijarvi.Heinrichs.2005.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: AlanenLaanijarvi.Heinrichs.2005
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Alley.GISP2.2000.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Alley.GISP2.2000.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Alley.GISP2.2000
# Created time series: 5 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\AlltnaFeitheSheilich.Birks.1975.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: AlltnaFeitheSheilich.Birks.1975.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: AlltnaFeitheSheilich.Birks.1975
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\AlpidiRobieiValBavona.Welten.1982.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: AlpidiRobieiValBavona.Welten.1982.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: AlpidiRobieiValBavona.Welten.1982
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Alsa.Mariscal.1993.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Alsa.Mariscal.1993.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Alsa.Mariscal.1993
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Alsopahok.Zatyko.2007.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Alsopahok.Zatyko.2007.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Alsopahok.Zatyko.2007
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Altenweiher.DeValk.1981.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Altenweiher.DeValk.1981.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Altenweiher.DeValk.1981
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Ammersee.vonGrafenstein.1996.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ammersee.vonGrafenstein.1996.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Ammersee.vonGrafenstein.1996
# Created time series: 4 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\AMP112.vanderBilt.2016.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: AMP112.vanderBilt.2016.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: AMP112.vanderBilt.2016
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Andy.Szeicz.1995.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Andy.Szeicz.1995.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Andy.Szeicz.1995
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Arapisto.Sarmaja-Korjonen.2007.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Arapisto.Sarmaja-Korjonen.2007.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Arapisto.Sarmaja-Korjonen.2007
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Atocas.Gauthier.1981.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Atocas.Gauthier.1981.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Atocas.Gauthier.1981
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Austerkjosen.Seppa.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Austerkjosen.Seppa.2009.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Austerkjosen.Seppa.2009
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\AwengCo.Li.2017.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: AwengCo.Li.2017.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: AwengCo.Li.2017
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\B997_321.Castaneda.2004.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: B997_321.Castaneda.2004.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: B997_321.Castaneda.2004
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\B997_324.Castaneda.2004.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: B997_324.Castaneda.2004.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: B997_324.Castaneda.2004
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\B997_327.Castaneda.2004.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: B997_327.Castaneda.2004.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: B997_327.Castaneda.2004
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BaiedeSeineestuary.Garnaud.2003.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BaiedeSeineestuary.Garnaud.2003.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BaiedeSeineestuary.Garnaud.2003
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BanksIsland-12.Gajewski.2000.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BanksIsland-12.Gajewski.2000.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BanksIsland-12.Gajewski.2000
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BanksIsland-15.Gajewski.2000.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BanksIsland-15.Gajewski.2000.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BanksIsland-15.Gajewski.2000
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BasadelaMoraLake.Tarrats.2018.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BasadelaMoraLake.Tarrats.2018.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BasadelaMoraLake.Tarrats.2018
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Basse-Ville.Voeltzel.1987.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Basse-Ville.Voeltzel.1987.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Basse-Ville.Voeltzel.1987
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Bastien.Bennett.1987.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Bastien.Bennett.1987.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Bastien.Bennett.1987
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BattleGround.Whitlock.1985.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BattleGround.Whitlock.1985.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BattleGround.Whitlock.1985
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BC01Lake.Peros.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BC01Lake.Peros.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BC01Lake.Peros.2010
# Created time series: 13 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Beaverhouse.Ritchie.1976.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Beaverhouse.Ritchie.1976.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Beaverhouse.Ritchie.1976
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BebrukasLake.Shulija.1967.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BebrukasLake.Shulija.1967.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BebrukasLake.Shulija.1967
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BeefPasture.Petersen.1985.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BeefPasture.Petersen.1985.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BeefPasture.Petersen.1985
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BellsLake.Szeicz.1995.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BellsLake.Szeicz.1995.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BellsLake.Szeicz.1995
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Berkut.Ilyashuk.2005.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Berkut.Ilyashuk.2005.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Berkut.Ilyashuk.2005
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Berry.Whitehead.1979.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Berry.Whitehead.1979.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Berry.Whitehead.1979
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BI2Lake.Gajewski.1992.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BI2Lake.Gajewski.1992.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BI2Lake.Gajewski.1992
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BiglandTarn.Barber.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BiglandTarn.Barber.2013.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BiglandTarn.Barber.2013
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Billys.Jacobson.1975.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Billys.Jacobson.1975.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Billys.Jacobson.1975
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BiskupinskieLake.Noryskiewicz.1995.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BiskupinskieLake.Noryskiewicz.1995.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BiskupinskieLake.Noryskiewicz.1995
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BJ8_03_10GGC.Linsley.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BJ8_03_10GGC.Linsley.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BJ8_03_10GGC.Linsley.2010
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BJ8_03_13GGC.Linsley.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BJ8_03_13GGC.Linsley.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BJ8_03_13GGC.Linsley.2010
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BJ8_03_70GGC.Linsley.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BJ8_03_70GGC.Linsley.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BJ8_03_70GGC.Linsley.2010
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Bjornfjell.Brooks.2006.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Bjornfjell.Brooks.2006.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Bjornfjell.Brooks.2006
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BledowoLake.Binka.1988.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BledowoLake.Binka.1988.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BledowoLake.Binka.1988
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BloodPond.Marsicek.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BloodPond.Marsicek.2013.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BloodPond.Marsicek.2013
# Created time series: 9 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BN7Lake.Gajewski.1991.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BN7Lake.Gajewski.1991.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BN7Lake.Gajewski.1991
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BoehnigseeGoldmoos.Markgraf.1969.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BoehnigseeGoldmoos.Markgraf.1969.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BoehnigseeGoldmoos.Markgraf.1969
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BolshieToroki.Zhilich.2017.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BolshieToroki.Zhilich.2017.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BolshieToroki.Zhilich.2017
# Created time series: 9 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Boone.White.1986.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Boone.White.1986.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Boone.White.1986
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BorderBeacon.Lamb.1985.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BorderBeacon.Lamb.1985.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BorderBeacon.Lamb.1985
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BoundaryPond.Mott.1977.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BoundaryPond.Mott.1977.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BoundaryPond.Mott.1977
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BrayaSo.vonGunten.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BrayaSo.vonGunten.2012.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BrayaSo.vonGunten.2012
# Created time series: 5 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Breitnau-Neuhof.Roesch.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Breitnau-Neuhof.Roesch.2009.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Breitnau-Neuhof.Roesch.2009
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\brurskardstjorni.Velle.2005.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: brurskardstjorni.Velle.2005.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: brurskardstjorni.Velle.2005
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BS79_38.Cacho.2001.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BS79_38.Cacho.2001.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BS79_38.Cacho.2001
# Created time series: 5 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\BuntesMoor.Weirich.1980.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: BuntesMoor.Weirich.1980.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: BuntesMoor.Weirich.1980
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Cadagno.Niemann.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Cadagno.Niemann.2012.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Cadagno.Niemann.2012
# Created time series: 11 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Camp11.Brubaker.1975.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Camp11.Brubaker.1975.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Camp11.Brubaker.1975
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CandelabraLake.Cwynar.1995.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CandelabraLake.Cwynar.1995.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CandelabraLake.Cwynar.1995
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CangoCave.Talma.1992.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CangoCave.Talma.1992.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CangoCave.Talma.1992
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CapeGhir.Kim.2007.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CapeGhir.Kim.2007.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CapeGhir.Kim.2007
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Caribou-Qubec.Jett.1992.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Caribou-Qubec.Jett.1992.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Caribou-Qubec.Jett.1992
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CaribouHill.Lamb.1985.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CaribouHill.Lamb.1985.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CaribouHill.Lamb.1985
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CarletonLake.Upiter.2014.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CarletonLake.Upiter.2014.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CarletonLake.Upiter.2014
# Created time series: 11 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Carp.Whitlock.1985.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Carp.Whitlock.1985.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Carp.Whitlock.1985
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CascadeFen.Maher.1963.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CascadeFen.Maher.1963.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CascadeFen.Maher.1963
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Castor.Larouche.NA.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Castor.Larouche.NA.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Castor.Larouche.NA
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CC04.Gibb.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CC04.Gibb.2015.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CC04.Gibb.2015
# Created time series: 5 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Century.Johnsen.1972.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Century.Johnsen.1972.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Century.Johnsen.1972
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CF8.Axford.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CF8.Axford.2011.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CF8.Axford.2011
# Created time series: 11 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CH2.Garralla.1992.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CH2.Garralla.1992.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CH2.Garralla.1992
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\ChallaLake.Damst.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: ChallaLake.Damst.2012.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: ChallaLake.Damst.2012
# Created time series: 4 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Chaohu.Li.2018.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Chaohu.Li.2018.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Chaohu.Li.2018
# Created time series: 5 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Chuna.Jones.2005.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Chuna.Jones.2005.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Chuna.Jones.2005
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Churruca.Caniupan.2014.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Churruca.Caniupan.2014.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Churruca.Caniupan.2014
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Clapeyret.deBeaulieu.1977.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Clapeyret.deBeaulieu.1977.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Clapeyret.deBeaulieu.1977
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\ClarksJunction.Wilmshurst.2007.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: ClarksJunction.Wilmshurst.2007.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: ClarksJunction.Wilmshurst.2007
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\ClearLakeIA.Baker.1992.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: ClearLakeIA.Baker.1992.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: ClearLakeIA.Baker.1992
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\ClearLakeIN.Bailey.1972.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: ClearLakeIN.Bailey.1972.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: ClearLakeIN.Bailey.1972
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\ClearPond.Hussey.1993.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: ClearPond.Hussey.1993.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: ClearPond.Hussey.1993
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CN01.Cheung.2017.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CN01.Cheung.2017.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CN01.Cheung.2017
# Created time series: 2 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Coghill.King.1986.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Coghill.King.1986.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Coghill.King.1986
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Compass.Macpherson.1986.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Compass.Macpherson.1986.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Compass.Macpherson.1986
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Copley.Fall.1997.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Copley.Fall.1997.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Copley.Fall.1997
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CoppermineSaddleback.Nichols.1975.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CoppermineSaddleback.Nichols.1975.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CoppermineSaddleback.Nichols.1975
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Corser.Nichols.2014.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Corser.Nichols.2014.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Corser.Nichols.2014
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CottonwoodLake.Grimm.1987.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CottonwoodLake.Grimm.1987.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CottonwoodLake.Grimm.1987
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\CottonwoodPassPond.Fall.1997.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: CottonwoodPassPond.Fall.1997.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: CottonwoodPassPond.Fall.1997
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Cranberry.McAndrews.NA.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Cranberry.McAndrews.NA.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Cranberry.McAndrews.NA
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\D13882.Tierney.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: D13882.Tierney.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: D13882.Tierney
# Created time series: 5 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\DajiuhuPeatland.Huang.2013.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: DajiuhuPeatland.Huang.2013.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: DajiuhuPeatland.Huang.2013
# Created time series: 4 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Dalene.Seppa.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Dalene.Seppa.2009.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Dalene.Seppa.2009
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Dalmutladdo.Bjune.2004.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Dalmutladdo.Bjune.2004.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Dalmutladdo.Bjune.2004
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\DANA12_11_2_GC01.VanNieuwenhove.2018.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: DANA12_11_2_GC01.VanNieuwenhove.2018.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: DANA12_11_2_GC01.VanNieuwenhove.2018
# Created time series: 5 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\DarzlubieForest.Polska-JasiewiczOwa.1996.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: DarzlubieForest.Polska-JasiewiczOwa.1996.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: DarzlubieForest.Polska-JasiewiczOwa.1996
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\DavisLake.Barnosky.1981.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: DavisLake.Barnosky.1981.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: DavisLake.Barnosky.1981
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Decoy.Szeicz.1991.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Decoy.Szeicz.1991.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Decoy.Szeicz.1991
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Delorme1.Bouchard.1982.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Delorme1.Bouchard.1982.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Delorme1.Bouchard.1982
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Delorme2.Bouchard.1982.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Delorme2.Bouchard.1982.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Delorme2.Bouchard.1982
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Deltasoe.Axford.2019.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Deltasoe.Axford.2019.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Deltasoe.Axford.2019
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Demont.Kapp.NA.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Demont.Kapp.NA.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Demont.Kapp.NA
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\DempsterPeatland.Porter.2019.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: DempsterPeatland.Porter.2019.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: DempsterPeatland.Porter.2019
# Created time series: 11 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Devils.Shuman.2016.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Devils.Shuman.2016.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Devils.Shuman.2016
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\DevonIceCap.Paterson.1977.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: DevonIceCap.Paterson.1977.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: DevonIceCap.Paterson.1977
# Created time series: 2 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\DevonIslandGlacier.McAndrews.1984.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: DevonIslandGlacier.McAndrews.1984.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: DevonIslandGlacier.McAndrews.1984
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\DolgoeLake.Wolfe.2000.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: DolgoeLake.Wolfe.2000.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: DolgoeLake.Wolfe.2000
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\DomeF.Uemura.2018.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: DomeF.Uemura.2018.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: DomeF.Uemura.2018
# Created time series: 14 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Donvold.Nilssen.1983.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Donvold.Nilssen.1983.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Donvold.Nilssen.1983
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Duck.Winkler.1985.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Duck.Winkler.1985.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Duck.Winkler.1985
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Dura-Moor.Seiwald.1980.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Dura-Moor.Seiwald.1980.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Dura-Moor.Seiwald.1980
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Duranunlak.EPD.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Duranunlak.EPD.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Duranunlak.EPD
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\DYE3.Dahl-Jensen.1998.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: DYE3.Dahl-Jensen.1998.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: DYE3.Dahl-Jensen.1998
# Created time series: 2 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Dye3.Vinther.2006.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Dye3.Vinther.2006.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Dye3.Vinther.2006
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\EagleTarn.Rees.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: EagleTarn.Rees.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: EagleTarn.Rees.2010
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\EC1.Gajewski.1993.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: EC1.Gajewski.1993.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: EC1.Gajewski.1993
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\EC2.Gajewski.1991.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: EC2.Gajewski.1991.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: EC2.Gajewski.1991
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\EDML.Stenni.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: EDML.Stenni.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: EDML.Stenni.2010
# Created time series: 9 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Egelsee.Larocque.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Egelsee.Larocque.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Egelsee.Larocque.2010
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\ELake.Ritchie.1976.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: ELake.Ritchie.1976.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: ELake.Ritchie.1976
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Eldora.Maher.1969.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Eldora.Maher.1969.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Eldora.Maher.1969
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Eleanor.Gavin.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Eleanor.Gavin.2011.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Eleanor.Gavin.2011
# Created time series: 11 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Elfstadalsvatn.Langdon.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Elfstadalsvatn.Langdon.2008.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Elfstadalsvatn.Langdon.2008
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\ElGygytgynCrater.Schwamborn.2006.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: ElGygytgynCrater.Schwamborn.2006.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: ElGygytgynCrater.Schwamborn.2006
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\EN32_PC6.Flower.2004.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: EN32_PC6.Flower.2004.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: EN32_PC6.Flower.2004
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Ennadai-1.Nichols.1967.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ennadai-1.Nichols.1967.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Ennadai-1.Nichols.1967
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Ennadai-2.Nichols.1975.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ennadai-2.Nichols.1975.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Ennadai-2.Nichols.1975
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\EPICADomeC.Stenni.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: EPICADomeC.Stenni.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: EPICADomeC.Stenni.2010
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\ERDC_092BX.Palmer.2003.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: ERDC_092BX.Palmer.2003.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: ERDC_092BX.Palmer.2003
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\ESM-1.Mackay.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: ESM-1.Mackay.2012.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: ESM-1.Mackay.2012
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Etangd'yCorMontana.Welten.1982.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Etangd'yCorMontana.Welten.1982.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Etangd'yCorMontana.Welten.1982
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\EW0408_66JC.Praetorius.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: EW0408_66JC.Praetorius.2015.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: EW0408_66JC.Praetorius.2015
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\EW0408_85JC.Praetorius.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: EW0408_85JC.Praetorius.2015.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: EW0408_85JC.Praetorius.2015
# Created time series: 10 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\FanLake.Foster.2016.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: FanLake.Foster.2016.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: FanLake.Foster.2016
# Created time series: 17 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Farewell.Hu.1998.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Farewell.Hu.1998.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Farewell.Hu.1998
# Created time series: 4 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\FauskeCave.Linge.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: FauskeCave.Linge.2009.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: FauskeCave.Linge.2009
# Created time series: 4 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Ferndale.Albert.1981.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ferndale.Albert.1981.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Ferndale.Albert.1981
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Flarken.Berglund.1966.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Flarken.Berglund.1966.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Flarken.Berglund.1966
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Flarken.Seppa.2005.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Flarken.Seppa.2005.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Flarken.Seppa.2005
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Flotatjonn.Seppa.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Flotatjonn.Seppa.2009.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Flotatjonn.Seppa.2009
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\FontaineHenry.Lespez.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: FontaineHenry.Lespez.2008.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: FontaineHenry.Lespez.2008
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Frozen.Rosenberg.2004.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Frozen.Rosenberg.2004.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Frozen.Rosenberg.2004
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Gammelheimvatnet.Seppa.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Gammelheimvatnet.Seppa.2009.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Gammelheimvatnet.Seppa.2009
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Gass.Webb.1983.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Gass.Webb.1983.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Gass.Webb.1983
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\GB1.Gajewski.1991.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: GB1.Gajewski.1991.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: GB1.Gajewski.1991
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\GB2.Gajewski.1993.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: GB2.Gajewski.1993.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: GB2.Gajewski.1993
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Gemini.Samartin.2017.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Gemini.Samartin.2017.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Gemini.Samartin.2017
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\GeoB10042_1.Setiawan.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: GeoB10042_1.Setiawan.2015.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: GeoB10042_1.Setiawan.2015
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\GeoB10043_3.Setiawan.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: GeoB10043_3.Setiawan.2015.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: GeoB10043_3.Setiawan.2015
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\GeoB10053_7.Mohtadi.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: GeoB10053_7.Mohtadi.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: GeoB10053_7.Mohtadi.2010
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\GeoB10069_3.Gibbons.2014.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: GeoB10069_3.Gibbons.2014.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: GeoB10069_3.Gibbons.2014
# Created time series: 8 entries
# ...
# extracting: JR244_GC528.Roberts.2016
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\JR51GC_35.Bendle.2007.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: JR51GC_35.Bendle.2007.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: JR51GC_35.Bendle.2007
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\K2.Fallu.2005.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: K2.Fallu.2005.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: K2.Fallu.2005
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Kaartlamminsuo.Rankama.1988.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Kaartlamminsuo.Rankama.1988.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Kaartlamminsuo.Rankama.1988
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KaiteCobreMayor.MartinChivelet.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KaiteCobreMayor.MartinChivelet.2011.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KaiteCobreMayor.MartinChivelet.2011
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Kansjon.EPD.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Kansjon.EPD.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Kansjon.EPD
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KardashinskiSwamp.Kremenetski.1995.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KardashinskiSwamp.Kremenetski.1995.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KardashinskiSwamp.Kremenetski.1995
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Karujarv.EPD.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Karujarv.EPD.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Karujarv.EPD
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Keele.Szeicz.1995.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Keele.Szeicz.1995.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Keele.Szeicz.1995
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Kenosee.Porter.1992.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Kenosee.Porter.1992.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Kenosee.Porter.1992
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KeystoneIronbog.Fall.1985.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KeystoneIronbog.Fall.1985.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KeystoneIronbog.Fall.1985
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Kharinei.Jones.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Kharinei.Jones.2011.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Kharinei.Jones.2011
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Khatanga-12Lake.Syrykh.2017.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Khatanga-12Lake.Syrykh.2017.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Khatanga-12Lake.Syrykh.2017
# Created time series: 2 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KinderlinskayaCave.Baker.2017.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KinderlinskayaCave.Baker.2017.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KinderlinskayaCave.Baker.2017
# Created time series: 12 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Kinnshaugen.Seppa.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Kinnshaugen.Seppa.2009.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Kinnshaugen.Seppa.2009
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Klotjaernen.Pollen.Sweden.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Klotjaernen.Pollen.Sweden.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Klotjaernen.Pollen.Sweden
# Created time series: 10 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\klotjarnen.Seppa.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: klotjarnen.Seppa.2009.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: klotjarnen.Seppa.2009
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KNR159_5_36GGC.Carlson.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KNR159_5_36GGC.Carlson.2008.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KNR159_5_36GGC.Carlson.2008
# Created time series: 9 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KNR159_JPC26.Antonarakou.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KNR159_JPC26.Antonarakou.2015.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KNR159_JPC26.Antonarakou.2015
# Created time series: 13 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KNR166_14_11JPC.Elmore.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KNR166_14_11JPC.Elmore.2015.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KNR166_14_11JPC.Elmore.2015
# Created time series: 9 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KNR166_JPC26.Schmidt.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KNR166_JPC26.Schmidt.2011.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KNR166_JPC26.Schmidt.2011
# Created time series: 9 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KNR166_JPC51.Schmidt.2012.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KNR166_JPC51.Schmidt.2012.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KNR166_JPC51.Schmidt.2012
# Created time series: 9 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KNR195_5_CDH23.Bova.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KNR195_5_CDH23.Bova.2015.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KNR195_5_CDH23.Bova.2015
# Created time series: 10 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KNR195_5_CDH26.Bova.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KNR195_5_CDH26.Bova.2015.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KNR195_5_CDH26.Bova.2015
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KoeycegizGoelue.EPD.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KoeycegizGoelue.EPD.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KoeycegizGoelue.EPD
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Komosomolskaia.Ciais.1992.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Komosomolskaia.Ciais.1992.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Komosomolskaia.Ciais.1992
# Created time series: 4 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Koucha.Herzschuh.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Koucha.Herzschuh.2009.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Koucha.Herzschuh.2009
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KP2.Seppa.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KP2.Seppa.2009.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KP2.Seppa.2009
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KR02Chironomid.Fortin.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KR02Chironomid.Fortin.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KR02Chironomid.Fortin.2010
# Created time series: 10 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KR02Pollen.Peros.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KR02Pollen.Peros.2008.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KR02Pollen.Peros.2008
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KT05_7_PC_02.Kawahata.2009.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KT05_7_PC_02.Kawahata.2009.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KT05_7_PC_02.Kawahata.2009
# Created time series: 9 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Kurupa.Boldt.2015.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Kurupa.Boldt.2015.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Kurupa.Boldt.2015
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Kusawa.Chakraborty.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Kusawa.Chakraborty.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Kusawa.Chakraborty.2010
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KY07_04_PC1.Kubota.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KY07_04_PC1.Kubota.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KY07_04_PC1.Kubota.2010
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Kyutyunda.Biskaborn.2016.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Kyutyunda.Biskaborn.2016.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Kyutyunda.Biskaborn.2016
# Created time series: 5 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\KZAI_01.Hardy.2018.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: KZAI_01.Hardy.2018.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: KZAI_01.Hardy.2018
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LacAurelie.Bajolle.2018.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LacAurelie.Bajolle.2018.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LacAurelie.Bajolle.2018
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LacColin.Mott.1977.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LacColin.Mott.1977.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LacColin.Mott.1977
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LacduSommet.Hausmann.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LacduSommet.Hausmann.2011.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LacduSommet.Hausmann.2011
# Created time series: 4 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LacFaribault.Larouche.1981.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LacFaribault.Larouche.1981.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LacFaribault.Larouche.1981
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LacGras.King.1986.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LacGras.King.1986.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LacGras.King.1986
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LacLeonard.Labelle.1984.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LacLeonard.Labelle.1984.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LacLeonard.Labelle.1984
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LacMartyne.McAndrews.NA.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LacMartyne.McAndrews.NA.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LacMartyne.McAndrews.NA
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LacMeleze.MacDonald.1987.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LacMeleze.MacDonald.1987.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LacMeleze.MacDonald.1987
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LacPatricia.McAndrews.1983.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LacPatricia.McAndrews.1983.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LacPatricia.McAndrews.1983
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LacPetel.King.1986.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LacPetel.King.1986.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LacPetel.King.1986
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Ladd.Shane.1993.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Ladd.Shane.1993.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: Ladd.Shane.1993
# Created time series: 6 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LagodeAjo.Allen.1996.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LagodeAjo.Allen.1996.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LagodeAjo.Allen.1996
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LagoDellAccesa.Finsinger.2010.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LagoDellAccesa.Finsinger.2010.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LagoDellAccesa.Finsinger.2010
# Created time series: 3 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LagoMoreno.Markgraf.2002.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LagoMoreno.Markgraf.2002.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LagoMoreno.Markgraf.2002
# Created time series: 10 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LagoVerdarolo.Samartin.2011.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LagoVerdarolo.Samartin.2011.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LagoVerdarolo.Samartin.2011
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LagunaChaplin.Punyasena.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LagunaChaplin.Punyasena.2008.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LagunaChaplin.Punyasena.2008
# Created time series: 8 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\LagunaSaladaChiprana.EPD.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: LagunaSaladaChiprana.EPD.lpd
# Finished read: 1 record
# extracting paleoData...
# extracting: LagunaSaladaChiprana.EPD
# Created time series: 7 entries
# C:\Users\arjun\Documents\TS Math Project 5\data\Laihalampi.Giesecke.2008.lpd
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# reading: Laihalampi.Giesecke.2008.lpd

# %%
illegal_nums = [2,6,21,38,78,79,113,122,130,132,143,144,205,212,220,
           230,231,253,255,285,304,338,353,371,395,416,433,453,
           478,481,482,490,506,520,527,532,544,562,570,580,583,
           595,600,602,603,604,608,624,628,635,639,649,665,677,695]
illegal = [[i for i in listdir() if i not in ['genetic_formatting.txt', '.ipynb_checkpoints']][i] for i in illegal_nums]
illegal.append('.ipynb_checkpoints')
illegal.append('genetic_formatting.txt')

# %%
import lipd
import os
import pandas as pd
import random
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score, f1_score
from copy import deepcopy

from math import sin, pi, e

cwd = 'C:\\Users\\arjun\\Documents\\TS Math Project 5\\data'

def listdir():
    if os.getcwd()=='C:\\Users\\arjun\\Documents\\TS Math Project 5\\data':
        return os.listdir()
    else:
        return os.listdir('data')

def lpd(path):
    d = {}
    print(cwd+"\\"+path)
    for i in lipd.extractTs(lipd.readLipd(cwd+'\\'+path)):        
        if i["paleoData_variableName"] in ['age','temperature']:
            d[i["paleoData_variableName"]] = i["paleoData_values"]
    return d

def start():
    data = {}
    for file in listdir():
        if file.endswith('.lpd'):
            data[file]=lpd(file)
    return data

def frame(file, sort = False):
    if sort:
        return pd.DataFrame(data[file]).sort_values('age')
    else:
        return pd.DataFrame(data[file])

# %%
count1 = 0
count2 = 1
L_bozo_list = []

print('The files that have conflicting lengths:\n')

llist = [i for i in listdir() if i not in ['genetic_formatting.txt', '.ipynb_checkpoints']]

for file in (llist):
    try:
        if count2<10:
            n = '  '
        else:
            n = ' '
        if len(data[llist[count1]]['age'])!=len(data[llist[count1]]['temperature']):
            L_bozo_list.append(count1)
            print(f"{count2}.{n}[{count1}][{llist[count1]}] {len(data[llist[count1]]['age']),len(data[llist[count1]]['temperature'])}")
            count2+=1
    except:
        L_bozo_list.append(count1)
        
    finally:
        count1+=1 
        
print("\nThe files in which 'temperature' doesn't exist\n")

count3 = 1
for item in L_bozo_list:
    if count3<10:
            n = '  '
    else:
            n = ' '
    print(f"{count3}.{n}[{item}][{llist[item]}]")
    count3+=1

# %%
lstdir = listdir()

# %%
def legal():
    return [x for x in lstdir if x not in illegal]

# %%
for file in legal():
    if frame(file).replace('nan',np.nan).isna().describe()['temperature']['freq'] != len(frame(file)) or frame(file).replace('nan',np.nan).isna().describe()['age']['freq'] != len(frame(file)):
        try:
            lstdir.remove(file)
        except:
            pass

# %%
#choices = random.sample(legal(),5)
choices = [
'DempsterPeatland.Porter.2019.lpd',
 'BloodPond.Marsicek.2013.lpd',
 'HomesteadScarp.McGlone.2010.lpd',
 'DajiuhuPeatland.Huang.2013.lpd',
 'MiddenCluster6.Harbert.2018.lpd'
]

# %%
highest_low = -(10**6)
lowest_high = 10**6

low_file = ''
high_file = ''

for i in choices:
    print(i)
    if frame(i,True)['age'][0] > highest_low:
        highest_low = frame(i,True)['age'][0]
        low_file = i
    if frame(i,True)['age'].to_list()[-1] < lowest_high:
        lowest_high = frame(i,True)['age'].to_list()[-1]
        high_file = i
((highest_low, low_file), (lowest_high, high_file)), lowest_high-highest_low
# Out:
# DempsterPeatland.Porter.2019.lpd
# BloodPond.Marsicek.2013.lpd
# HomesteadScarp.McGlone.2010.lpd
# DajiuhuPeatland.Huang.2013.lpd
# MiddenCluster6.Harbert.2018.lpd
# (((183.33, 'DajiuhuPeatland.Huang.2013.lpd'),
#   (12246.9, 'HomesteadScarp.McGlone.2010.lpd')),
#  12063.57)

# %%
for i in choices:
    print(i)
    frame(i,True).plot('age')
# Out:
# DempsterPeatland.Porter.2019.lpd
# BloodPond.Marsicek.2013.lpd
# HomesteadScarp.McGlone.2010.lpd
# DajiuhuPeatland.Huang.2013.lpd
# MiddenCluster6.Harbert.2018.lpd

# %%
desired_x = [x*10 for x in list(range(int((highest_low+10)//10),int((lowest_high)//10)+1))]

# %%
final_frames = {}
for choice in choices:
    age = frame(choice)['age'].to_list()+[x for x in desired_x if x not in frame(choice)['age'].to_list()]
    temp = frame(choice)['temperature'].to_list()+[np.nan for i in range(len([x for x in desired_x if x not in frame(choice)['age'].to_list()]))]
    df = pd.DataFrame([age,temp]).transpose().rename(columns = {0:'age',1:'temperature'}).sort_values('age').interpolate()
    final_frames[choice] = df[df['age'].isin(desired_x)].reset_index(drop = True)

# %%
#prints the plot of the data in its original form, and then the interpolated version below
for file, dframe in final_frames.items():
    print(file)
    frame(file,True).plot('age')
    dframe.plot('age')
# Out:
# DempsterPeatland.Porter.2019.lpd
# BloodPond.Marsicek.2013.lpd
# HomesteadScarp.McGlone.2010.lpd
# DajiuhuPeatland.Huang.2013.lpd
# MiddenCluster6.Harbert.2018.lpd

# %%
megadf = 0
for file, dframe in final_frames.items():
    megadf += dframe
megadf /= 5
megadf
# Out:
#           age  temperature
# 0       190.0     5.629862
# 1       200.0     5.777043
# 2       210.0     5.919224
# 3       220.0     5.982833
# 4       230.0     6.046443
# ...       ...          ...
# 1201  12200.0     2.875129
# 1202  12210.0     2.868347
# 1203  12220.0     2.846065
# 1204  12230.0     2.856716
# 1205  12240.0     2.891028
#
# [1206 rows x 2 columns]

# %%
megadf.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
def get(n, index = False):
    if index:
        return megadf.set_index('age').iloc[n][0]
    else:
        return megadf.set_index('age').loc[n][0]

# %%
megadf.describe()
# Out:
#               age  temperature
# count   1206.0000  1206.000000
# mean    6215.0000     5.657444
# std     3482.8652     0.951690
# min      190.0000     2.846065
# 25%     3202.5000     5.208478
# 50%     6215.0000     5.946068
# 75%     9227.5000     6.318739
# max    12240.0000     7.077167

# %%
(megadf['temperature']//1).to_list().index(2)
# Out:
# 1174

# %%
get(12000)
# Out:
# 3.027111295352269

# %%
get(4000)
# Out:
# 7.012902746798913

# %%
get(1174,True)
# Out:
# 2.9958125361813375

# %%
megadf.iloc[1174]
# Out:
# age            11930.000000
# temperature        2.995813
# Name: 1174, dtype: float64

# %%
megadf.iloc[377]
# Out:
# age            3960.000000
# temperature       7.037402
# Name: 377, dtype: float64

# %%
flipped = deepcopy(megadf)
flipped['age'] *= -1

# %%
flipped.sort_values('age').reset_index(drop = True).plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
def function1(x):
    return (-0.0000000625)*(x-4000)**2+7

# %%
megadf['Function 1'] = [function1(x) for x in megadf['age']]

# %%
megadf.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
mean_squared_error(y_true = megadf['temperature'],  y_pred = megadf['Function 1'], squared = False)
# Out:
# 0.6459856419633645

# %%
r2_score(y_true = megadf['temperature'],  y_pred = megadf['Function 2'])
# Out:
# 0.6401404253943973

# %%
r2_score(y_true = megadf['temperature'],  y_pred = megadf['Function 1'])
# Out:
# 0.5388790869072642

# %%
mlist = [(list(megadf.drop(columns='Function 1').transpose()[i])) for i in megadf.drop(columns='Function 1').transpose()]
with open('genetic_formatting.txt', 'w') as f:
    for a,b in mlist:
        f.write(f"{a} {b}")
        f.write('\n')
    f.close()

# %%
def function2(x):
    return (-0.000000045)*(x-4000)**2+6.5+0.5*sin(0.01*x)

# %%
megadf['Function 2'] = [function2(x) for x in megadf['age']]

# %%
megadf.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
def function3b(x):#1.2e^{-\left(0.001\left(x-3000\right)\right)^{2}}\cdot0.5*\sin(0.01*x)
    a = 1.2*e**(-(0.001*(x-3000))**2)*0.5*sin(0.01*x)
    b = 1*e**(-(0.0007*(x-1000))**2)*0.5*sin(0.006*(x+50))
    c = 0.9*e**(-(0.002*(x-8200))**2)*0.6*sin(0.009*x)
    d = (0.5*e**(-(0.001*(x-11000))**2))*1.0*sin(0.01*x)
    return a + b + c + d

def function3(x):
    #return (-0.000000045)*(x-4000)**2+5.5+0.5*sin(0.01*x)-0.6*sin(0.0013*x+1)+0.0001*x+1.2*e**(-(0.0005*(x))**2)+0.8*e**(-(0.0005*(x-5000))**2)
    #(-0.000000045)*(x-4000)^{2}+6.5+0.8e^{-\left(0.0005\left(x-3000\right)\right)^{2}}+-0.8e^{-\left(0.0008\left(x-5500\right)\right)^{2}}+e^{-\left(0.0008\left(x-7000\right)\right)^{2}}
    a = (-0.000000045)*(x-4000)**2+6.5
    b = 0.2*e**(-(0.0008*(x-3000))**2)
    c = -0.4*e**(-(0.0008*(x-5000))**2)
    d = 0.7*e**(-(0.0008*(x-8000))**2)
    f = -0.4*e**(-(0.0008*(x-10000))**2)
    g = -0.6*e**(-(0.0008*(x-900))**2)
    h = -0.7*e**(-(0.002*(x-12300))**2)#-e^{-\left(0.0015\left(x-12000\right)\right)^{2}}
    return a + b + c + d + f + function3b(x) + g + h

# %%
megadf['Function 3'] = [function3(x) for x in megadf['age']]

# %%
get()

# %%
megadf.drop(columns = ['Function 1', 'Function 2', 'Function 3']).plot('age')
megadf.drop(columns = ['Function 1', 'Function 2', 'temperature']).plot('age')
megadf.drop(columns = ['Function 1', 'Function 2']).plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
mean_squared_error(y_true = megadf['temperature'],  y_pred = megadf['Function 3'])
# Out:
# 0.08951430769996849

# %%
r2_score(y_true = megadf['temperature'],  y_pred = megadf['Function 3'])
# Out:
# 0.9010851388169703

# %%
list(final_frames)
# Out:
# ['DempsterPeatland.Porter.2019.lpd',
#  'BloodPond.Marsicek.2013.lpd',
#  'HomesteadScarp.McGlone.2010.lpd',
#  'DajiuhuPeatland.Huang.2013.lpd',
#  'MiddenCluster6.Harbert.2018.lpd']

# %%
one = final_frames['DempsterPeatland.Porter.2019.lpd']
one.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
one.describe()
# Out:
#               age  temperature
# count   1206.0000  1206.000000
# mean    6215.0000    -0.478814
# std     3482.8652     0.554007
# min      190.0000    -1.990588
# 25%     3202.5000    -0.884462
# 50%     6215.0000    -0.500000
# 75%     9227.5000     0.040682
# max    12240.0000     0.500000

# %%
def get_from(df, n, index = False):
    if index:
        return df.set_index('age').iloc[n][0]
    else:
        return df.set_index('age').loc[n][0]

# %%
get_from(one, 10370)
# Out:
# 0.5

# %%
get_from(one, 2000)
# Out:
# -1.003448275862069

# %%
one[(one['age'] > 0) & (one['age'] < 6000)].plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
def one_function1(x):
    return (-0.75)*sin((x+2185)*2*pi/16470)-0.25

# %%
one['Function 1'] = [one_function1(i) for i in one['age']]

# %%
one.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
def one_function2(x):
    return (-0.75)*sin((x+2185)*2*pi/16470)-0.25+0.3*sin(0.005*x)

# %%
one['Function 2'] = [one_function2(i) for i in one['age']]

# %%
one.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
mean_squared_error(one['temperature'], one['Function 1'], squared = False)
# Out:
# 0.7267139309118534

# %%
r2_score(one['temperature'], one['Function 2'])
# Out:
# -0.8087370257595397

# %%
megadf.corr()
# Out:
#                   age  temperature  Function 1  Function 2
# age          1.000000    -0.605489   -0.818113   -0.754187
# temperature -0.605489     1.000000    0.871392    0.816258
# Function 1  -0.818113     0.871392    1.000000    0.921347
# Function 2  -0.754187     0.816258    0.921347    1.000000

# %%
list(final_frames)
# Out:
# ['DempsterPeatland.Porter.2019.lpd',
#  'BloodPond.Marsicek.2013.lpd',
#  'HomesteadScarp.McGlone.2010.lpd',
#  'DajiuhuPeatland.Huang.2013.lpd',
#  'MiddenCluster6.Harbert.2018.lpd']

# %%
two = final_frames['BloodPond.Marsicek.2013.lpd']

# %%
two.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
get_from(two, 12000)
# Out:
# -5.0394355635

# %%
def two_function1(x):
    return (-1/6400000)*(x-4000)**2+4

# %%
two['Function 1'] = [two_function1(x) for x in two['age']]

# %%
two.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
r2_score(two['temperature'], two['Function 1'])
# Out:
# 0.712159488995233

# %%
def two_function2(x):
    return (-0.00000012625)*(x-4400)**2+3.5+sin(0.0075*x)

# %%
two['Function 2'] = [two_function2(x) for x in two['age']]

# %%
two.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
r2_score(two['temperature'], two['Function 2'])
# Out:
# 0.680514394064726

# %%
list(final_frames)
# Out:
# ['DempsterPeatland.Porter.2019.lpd',
#  'BloodPond.Marsicek.2013.lpd',
#  'HomesteadScarp.McGlone.2010.lpd',
#  'DajiuhuPeatland.Huang.2013.lpd',
#  'MiddenCluster6.Harbert.2018.lpd']

# %%
three = final_frames['HomesteadScarp.McGlone.2010.lpd']

# %%
three.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# seems too difficult to even attempt at modeling

# %%
# move on to fourth

# %%
four = final_frames['DajiuhuPeatland.Huang.2013.lpd']

# %%
four.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
four[(four['age'] > 0) & (four['age']<2000)].plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
def four_function1(x):
    return (-0.0000001)*(x-7000)**2+5

# %%
four['Function 1'] = [four_function1(x) for x in four['age']]

# %%
four.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
def four_function2(x):
    return (-0.0000001)*(x-7000)**2+5+sin(0.01*x)

# %%
four['Function 2'] = [four_function2(x) for x in four['age']]

# %%
four.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
r2_score(four['temperature'], four['Function 1'])
# Out:
# 0.5457512593994214

# %%
r2_score(four['temperature'], four['Function 2'])
# Out:
# 0.13704996465630104

# %%
# epic fail, looks difficult to improve

# %%
list(final_frames)
# Out:
# ['DempsterPeatland.Porter.2019.lpd',
#  'BloodPond.Marsicek.2013.lpd',
#  'HomesteadScarp.McGlone.2010.lpd',
#  'DajiuhuPeatland.Huang.2013.lpd',
#  'MiddenCluster6.Harbert.2018.lpd']

# %%
five = final_frames['MiddenCluster6.Harbert.2018.lpd']

# %%
five.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
def five_function1(x):
    return (-x/3000)+17

# %%
five['Function 1'] = [five_function1(x) for x in five['age']]

# %%
five.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
def five_function2(x):
    return (-x/3000)+19 + 2*sin(0.01*x)

# %%
five['Function 2'] = [five_function2(x) for x in five['age']]

# %%
five.plot('age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
r2_score(five['temperature'],five['Function 1'])
# Out:
# 0.22247084592783595

# %%
r2_score(five['temperature'],five['Function 2'])
# Out:
# -0.47815724169885687

# %%
# how come. the model. is worse. when i make it better.

# %%
# another epic fail

# %%
# and thats probably a wrap

# %%
# bye guys
